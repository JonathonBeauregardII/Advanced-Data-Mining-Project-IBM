# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %matplotlib inline

# %%
# The code was removed by DSX for sharing.
# Out:
#    Unnamed: 0          CASE_STATUS  \
# 0           1  CERTIFIED-WITHDRAWN
# 1           2  CERTIFIED-WITHDRAWN
# 2           3  CERTIFIED-WITHDRAWN
# 3           4  CERTIFIED-WITHDRAWN
# 4           5            WITHDRAWN
#
#                                        EMPLOYER_NAME  \
# 0                             UNIVERSITY OF MICHIGAN
# 1                             GOODMAN NETWORKS, INC.
# 2                          PORTS AMERICA GROUP, INC.
# 3  GATES CORPORATION, A WHOLLY-OWNED SUBSIDIARY O...
# 4                          PEABODY INVESTMENTS CORP.
#
#                         SOC_NAME                     JOB_TITLE  \
# 0  BIOCHEMISTS AND BIOPHYSICISTS  POSTDOCTORAL RESEARCH FELLOW
# 1               CHIEF EXECUTIVES       CHIEF OPERATING OFFICER
# 2               CHIEF EXECUTIVES         CHIEF PROCESS OFFICER
# 3               CHIEF EXECUTIVES   REGIONAL PRESIDEN, AMERICAS
# 4               CHIEF EXECUTIVES  PRESIDENT MONGOLIA AND INDIA
#
# ...

# %%
data = df_data_1
#data.dropna(inplace=True)

#data1 = np.array(data)
#this is a numpy array, may be better to switch to it later

# %%
data.head()
# Out:
#    Unnamed: 0          CASE_STATUS  \
# 0           1  CERTIFIED-WITHDRAWN
# 1           2  CERTIFIED-WITHDRAWN
# 2           3  CERTIFIED-WITHDRAWN
# 3           4  CERTIFIED-WITHDRAWN
# 4           5            WITHDRAWN
#
#                                        EMPLOYER_NAME  \
# 0                             UNIVERSITY OF MICHIGAN
# 1                             GOODMAN NETWORKS, INC.
# 2                          PORTS AMERICA GROUP, INC.
# 3  GATES CORPORATION, A WHOLLY-OWNED SUBSIDIARY O...
# 4                          PEABODY INVESTMENTS CORP.
#
#                         SOC_NAME                     JOB_TITLE  \
# 0  BIOCHEMISTS AND BIOPHYSICISTS  POSTDOCTORAL RESEARCH FELLOW
# 1               CHIEF EXECUTIVES       CHIEF OPERATING OFFICER
# 2               CHIEF EXECUTIVES         CHIEF PROCESS OFFICER
# 3               CHIEF EXECUTIVES   REGIONAL PRESIDEN, AMERICAS
# 4               CHIEF EXECUTIVES  PRESIDENT MONGOLIA AND INDIA
#
# ...

# %%
slitstates=data['WORKSITE'].str.split(',', expand=True).astype(str)
#In this cell, we seperate the worksite into two coloumns; city and state

# %%
data['WORKSITE']=slitstates[1]
data.head()
#We then replace the value in the data to generalize and only have the state.
# Out:
#    Unnamed: 0          CASE_STATUS  \
# 0           1  CERTIFIED-WITHDRAWN
# 1           2  CERTIFIED-WITHDRAWN
# 2           3  CERTIFIED-WITHDRAWN
# 3           4  CERTIFIED-WITHDRAWN
# 4           5            WITHDRAWN
#
#                                        EMPLOYER_NAME  \
# 0                             UNIVERSITY OF MICHIGAN
# 1                             GOODMAN NETWORKS, INC.
# 2                          PORTS AMERICA GROUP, INC.
# 3  GATES CORPORATION, A WHOLLY-OWNED SUBSIDIARY O...
# 4                          PEABODY INVESTMENTS CORP.
#
#                         SOC_NAME                     JOB_TITLE  \
# 0  BIOCHEMISTS AND BIOPHYSICISTS  POSTDOCTORAL RESEARCH FELLOW
# 1               CHIEF EXECUTIVES       CHIEF OPERATING OFFICER
# 2               CHIEF EXECUTIVES         CHIEF PROCESS OFFICER
# 3               CHIEF EXECUTIVES   REGIONAL PRESIDEN, AMERICAS
# 4               CHIEF EXECUTIVES  PRESIDENT MONGOLIA AND INDIA
#
# ...

# %%
yearly = data.groupby('WORKSITE')
yearly['CASE_STATUS'].count().sort_values(ascending=False)
#yearly['CASE_STATUS'].count(h).plot(kind='bar')

#Here we start to get an idea about the data. We can see how many states recieve a vise request, and we order by this.
# Out:
# WORKSITE
#  CALIFORNIA              559940
#  TEXAS                   294454
#  NEW YORK                291410
#  NEW JERSEY              214076
#  ILLINOIS                160814
#  MASSACHUSETTS           116466
#  PENNSYLVANIA            109959
#  FLORIDA                 105773
#  GEORGIA                 103167
#  WASHINGTON              102801
#  VIRGINIA                 90028
#  MICHIGAN                 82964
#  NORTH CAROLINA           79672
#  OHIO                     76575
#  MARYLAND                 56256
#  CONNECTICUT              50253
#  MINNESOTA                48685
#  ARIZONA                  42054
#  MISSOURI                 34813
#  WISCONSIN                32672
#  COLORADO                 32037
#  INDIANA                  30516
#  TENNESSEE                27672
#  OREGON                   23790
#  DISTRICT OF COLUMBIA     22708
#  DELAWARE                 18138
#  IOWA                     16743
#  ARKANSAS                 14762
#  KANSAS                   13782
# ...

# %%
years = [2011, 2012, 2013, 2014, 2015, 2016]
for year in years:
    filtered = data[data['YEAR'] == year]
    print(year)
    print('---')
    print(filtered.groupby('EMPLOYER_NAME')['CASE_STATUS'].count().sort_values(ascending=False).head(10))
    print('\n')
# Out:
# 2011
# ---
# EMPLOYER_NAME
# TATA CONSULTANCY SERVICES LIMITED                  5416
# MICROSOFT CORPORATION                              4253
# DELOITTE CONSULTING LLP                            3621
# WIPRO LIMITED                                      3028
# COGNIZANT TECHNOLOGY SOLUTIONS U.S. CORPORATION    2721
# LARSEN & TOUBRO INFOTECH LIMITED                   2105
# INTEL CORPORATION                                  1952
# IBM CORPORATION                                    1822
# HCL AMERICA, INC.                                  1699
# DELOITTE & TOUCHE LLP                              1391
# Name: CASE_STATUS, dtype: int64
#
#
# 2012
# ---
# EMPLOYER_NAME
# INFOSYS LIMITED                      15818
# WIPRO LIMITED                         7182
# TATA CONSULTANCY SERVICES LIMITED     6735
# DELOITTE CONSULTING LLP               4727
# IBM INDIA PRIVATE LIMITED             4074
# MICROSOFT CORPORATION                 4067
# ACCENTURE LLP                         2619
# ...

# %%
data.EMPLOYER_NAME
# Out:
# 0                                     UNIVERSITY OF MICHIGAN
# 1                                     GOODMAN NETWORKS, INC.
# 2                                  PORTS AMERICA GROUP, INC.
# 3          GATES CORPORATION, A WHOLLY-OWNED SUBSIDIARY O...
# 4                                  PEABODY INVESTMENTS CORP.
# 5                                    BURGER KING CORPORATION
# 6                           BT AND MK ENERGY AND COMMODITIES
# 7                            GLOBO MOBILE TECHNOLOGIES, INC.
# 9                                  LESSARD INTERNATIONAL LLC
# 10                                        H.J. HEINZ COMPANY
# 11                                   DOW CORNING CORPORATION
# 13                                             BIOCAIR, INC.
# 14                                NEWMONT MINING CORPORATION
# 15                                              VRICON, INC.
# 16                               CARDIAC SCIENCE CORPORATION
# ...

# %%
case = data.groupby('CASE_STATUS')
case['CASE_STATUS'].count().sort_values(ascending=False)
#case['CASE_STATUS'].count().plot(kind='bar')
#see number of cases and ther classification type
# Out:
# CASE_STATUS
# CERTIFIED                                             2615623
# CERTIFIED-WITHDRAWN                                    202659
# DENIED                                                  94346
# WITHDRAWN                                               89799
# PENDING QUALITY AND COMPLIANCE REVIEW - UNASSIGNED         15
# REJECTED                                                    2
# INVALIDATED                                                 1
# Name: CASE_STATUS, dtype: int64

# %%
data[:].sort_values(['PREVAILING_WAGE'], ascending=[False])
#data[:].sort_values(['PREVAILING_WAGE'], ascending=[False]).to_csv('test.csv', index=False)

#the first line displays the information, the second line save it to a csv file
#needs to be filtered in some way, seeing some crazt numbers for income, whats up with that???
# Out:
#          Unnamed: 0 CASE_STATUS  \
# 2163248     2163249      DENIED
# 2797982     2797983      DENIED
# 1673867     1673868      DENIED
# 1819718     1819719      DENIED
# 2775906     2775907      DENIED
# 1547574     1547575      DENIED
# 1668384     1668385      DENIED
# 1805875     1805876      DENIED
# 2796071     2796072   WITHDRAWN
# 1698325     1698326      DENIED
# 2586866     2586867      DENIED
# 1780069     1780070      DENIED
# 2184108     2184109   WITHDRAWN
# 2190087     2190088      DENIED
# 2191003     2191004      DENIED
# 2685667     2685668      DENIED
# 2522246     2522247      DENIED
# 2921196     2921197      DENIED
# 5579           5580      DENIED
# 2831024     2831025      DENIED
# 2054920     2054921      DENIED
# 633103       633104      DENIED
# 2989391     2989392      DENIED
# 813742       813743      DENIED
# 1899911     1899912      DENIED
# 774072       774073      DENIED
# 2905942     2905943   CERTIFIED
# 2255296     2255297   WITHDRAWN
# ...
